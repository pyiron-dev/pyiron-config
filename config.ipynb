# %%
from pyiron_base import Project

# %%
pr = Project("test")

# %%
pr.state.settings.configuration
# Out:
# {'user': 'pyiron',
#  'resource_paths': [],
#  'project_paths': [],
#  'connection_timeout': 60,
#  'sql_connection_string': None,
#  'sql_table_name': 'jobs_pyiron',
#  'sql_view_connection_string': None,
#  'sql_view_table_name': None,
#  'sql_view_user': None,
#  'sql_view_user_key': None,
#  'sql_file': '/home/jovyan/pyiron.db',
#  'sql_host': None,
#  'sql_type': 'SQLite',
#  'sql_user_key': None,
#  'sql_database': None,
#  'project_check_enabled': 0,
#  'disable_database': 1}
